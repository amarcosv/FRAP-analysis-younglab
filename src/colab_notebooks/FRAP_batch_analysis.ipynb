# %% [markdown]
# # **FRAP Batch Analysis Pipeline**
# ---

# %% [markdown]
# # **Prepare environment and load dependencies**

# %%
#Install python packages
# !pip3 install --upgrade pip
# !pip install czitools
# !pip install pylibCZIrw

# !pip install bioio
# !pip install bioio-czi
# !pip install scikit_posthocs
# !pip install zarr
# !pip install statannotations


#Download last version of analysis code from repository
# !git clone https://github.com/amarcosv/FRAP-analysis-younglab -b develop
# %cd /content/FRAP-analysis-younglab/
# %ls
# !git pull origin develop
# %cd /content/FRAP-analysis-younglab/src

#Import libraries
import sys
sys.path.append('/content/FRAP-analysis-younglab/src/tools')
import frap_tools
import io_tools as io_tools
import processing_tools as processing_tools
from matplotlib import pyplot as plt
import pandas as pd
import os
import seaborn as sns
from matplotlib.ticker import FormatStrFormatter
# Out:
# Requirement already satisfied: pip in /usr/local/lib/python3.13/dist-packages (24.1.2)
# Collecting pip
#   Downloading pip-26.2.1-py3-none-any.whl.metadata (4.6 kB)
# Downloading pip-26.2.1-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 21.8 MB/s eta 0:00:00
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# Successfully installed pip-26.2.1
# Collecting czitools
#   Downloading czitools-0.25.1-py3-none-any.whl.metadata (17 kB)
# Collecting pylibCZIrw>=5 (from czitools)
#   Downloading pylibczirw-6.1.0-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.1 kB)
# Requirement already satisfied: progressbar2 in /usr/local/lib/python3.13/dist-packages (from czitools) (4.5.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.13/dist-packages (from czitools) (2.1.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.13/dist-packages (from czitools) (2.2.3)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.13/dist-packages (from czitools) (2.9.0.post0)
# Requirement already satisfied: python-box[all] in /usr/local/lib/python3.13/dist-packages (from czitools) (7.4.1)
# Collecting czifile>=2026.6.6 (from czitools)
#   Downloading czifile-2026.8.16-py3-none-any.whl.metadata (16 kB)
# Collecting loguru (from czitools)
#   Downloading loguru-0.7.3-py3-none-any.whl.metadata (22 kB)
# Collecting colorlog>=6.8.2 (from czitools)
#   Downloading colorlog-6.12.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.13/dist-packages (from czitools) (2.13.5)
# Requirement already satisfied: xarray in /usr/local/lib/python3.13/dist-packages (from czitools) (2025.12.0)
# Requirement already satisfied: dask[array] in /usr/local/lib/python3.13/dist-packages (from czitools) (2026.8.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.13/dist-packages (from czitools) (2.32.4)
# Collecting validators (from czitools)
#   Downloading validators-0.35.0-py3-none-any.whl.metadata (3.9 kB)
# Collecting zarr>=3.0 (from czitools)
#   Downloading zarr-3.4.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.13/dist-packages (from czitools) (3.10.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.13/dist-packages (from czitools) (13.9.4)
# Collecting imagecodecs>=2026.8.16 (from czifile>=2026.6.6->czitools)
#   Downloading imagecodecs-2026.8.16-cp312-abi3-manylinux_2_28_x86_64.whl.metadata (24 kB)
# Requirement already satisfied: cmake in /usr/local/lib/python3.13/dist-packages (from pylibCZIrw>=5->czitools) (3.31.10)
# Collecting xmltodict (from pylibCZIrw>=5->czitools)
#   Downloading xmltodict-1.0.4-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.13/dist-packages (from pylibCZIrw>=5->czitools) (26.3)
# Collecting donfig>=0.8 (from zarr>=3.0->czitools)
#   Downloading donfig-0.8.1.post1-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: google-crc32c>=1.5 in /usr/local/lib/python3.13/dist-packages (from zarr>=3.0->czitools) (1.8.0)
# Collecting msgspec>=0.19 (from zarr>=3.0->czitools)
#   Downloading msgspec-0.21.1-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (5.8 kB)
# Collecting numcodecs>=0.14 (from zarr>=3.0->czitools)
#   Downloading numcodecs-0.17.0-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (3.2 kB)
# Requirement already satisfied: typing-extensions>=4.14 in /usr/local/lib/python3.13/dist-packages (from zarr>=3.0->czitools) (4.16.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.13/dist-packages (from donfig>=0.8->zarr>=3.0->czitools) (6.0.3)
# Requirement already satisfied: click>=8.1 in /usr/local/lib/python3.13/dist-packages (from dask[array]->czitools) (8.5.0)
# Requirement already satisfied: cloudpickle>=3.0.0 in /usr/local/lib/python3.13/dist-packages (from dask[array]->czitools) (3.1.2)
# Requirement already satisfied: fsspec>=2021.09.0 in /usr/local/lib/python3.13/dist-packages (from dask[array]->czitools) (2025.12.0)
# Requirement already satisfied: partd>=1.4.0 in /usr/local/lib/python3.13/dist-packages (from dask[array]->czitools) (1.4.2)
# Requirement already satisfied: toolz>=0.12.0 in /usr/local/lib/python3.13/dist-packages (from dask[array]->czitools) (0.12.1)
# Requirement already satisfied: locket in /usr/local/lib/python3.13/dist-packages (from partd>=1.4.0->dask[array]->czitools) (1.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib->czitools) (1.4.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.13/dist-packages (from matplotlib->czitools) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.13/dist-packages (from matplotlib->czitools) (4.65.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib->czitools) (1.5.1)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.13/dist-packages (from matplotlib->czitools) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib->czitools) (3.3.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.13/dist-packages (from python-dateutil->czitools) (1.17.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.13/dist-packages (from pandas->czitools) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.13/dist-packages (from pandas->czitools) (2026.4)
# Requirement already satisfied: python-utils>=3.8.1 in /usr/local/lib/python3.13/dist-packages (from progressbar2->czitools) (4.0.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.13/dist-packages (from pydantic->czitools) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.5 in /usr/local/lib/python3.13/dist-packages (from pydantic->czitools) (2.46.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.13/dist-packages (from pydantic->czitools) (0.4.4)
# Collecting ruamel.yaml>=0.19.1 (from python-box[all]->czitools)
#   Downloading ruamel_yaml-0.19.1-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: toml in /usr/local/lib/python3.13/dist-packages (from python-box[all]->czitools) (0.10.2)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.13/dist-packages (from python-box[all]->czitools) (1.2.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests->czitools) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.13/dist-packages (from requests->czitools) (3.19)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.13/dist-packages (from requests->czitools) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.13/dist-packages (from requests->czitools) (2026.7.22)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.13/dist-packages (from rich->czitools) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.13/dist-packages (from rich->czitools) (2.21.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.13/dist-packages (from markdown-it-py>=2.2.0->rich->czitools) (0.1.2)
# Downloading czitools-0.25.1-py3-none-any.whl (161 kB)
# Downloading colorlog-6.12.0-py3-none-any.whl (12 kB)
# Downloading czifile-2026.8.16-py3-none-any.whl (66 kB)
# Downloading imagecodecs-2026.8.16-cp312-abi3-manylinux_2_28_x86_64.whl (28.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 28.1/28.1 MB 107.8 MB/s  0:00:00
# Downloading pylibczirw-6.1.0-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 44.0 MB/s  0:00:00
# Downloading zarr-3.4.0-py3-none-any.whl (376 kB)
# Downloading donfig-0.8.1.post1-py3-none-any.whl (21 kB)
# Downloading msgspec-0.21.1-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (225 kB)
# Downloading numcodecs-0.17.0-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 42.3 MB/s  0:00:00
# Downloading loguru-0.7.3-py3-none-any.whl (61 kB)
# Downloading ruamel_yaml-0.19.1-py3-none-any.whl (118 kB)
# Downloading validators-0.35.0-py3-none-any.whl (44 kB)
# Downloading xmltodict-1.0.4-py3-none-any.whl (13 kB)
# Installing collected packages: xmltodict, validators, ruamel.yaml, numcodecs, msgspec, loguru, imagecodecs, donfig, colorlog, zarr, pylibCZIrw, czifile, czitools
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13/13 [czitools]
# Successfully installed colorlog-6.12.0 czifile-2026.8.16 czitools-0.25.1 donfig-0.8.1.post1 imagecodecs-2026.8.16 loguru-0.7.3 msgspec-0.21.1 numcodecs-0.17.0 pylibCZIrw-6.1.0 ruamel.yaml-0.19.1 validators-0.35.0 xmltodict-1.0.4 zarr-3.4.0
# Requirement already satisfied: pylibCZIrw in /usr/local/lib/python3.13/dist-packages (6.1.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.13/dist-packages (from pylibCZIrw) (2.1.3)
# Requirement already satisfied: cmake in /usr/local/lib/python3.13/dist-packages (from pylibCZIrw) (3.31.10)
# Requirement already satisfied: xmltodict in /usr/local/lib/python3.13/dist-packages (from pylibCZIrw) (1.0.4)
# Requirement already satisfied: validators in /usr/local/lib/python3.13/dist-packages (from pylibCZIrw) (0.35.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.13/dist-packages (from pylibCZIrw) (26.3)
# Collecting bioio
#   Downloading bioio-3.5.1-py3-none-any.whl.metadata (8.6 kB)
# Collecting bioio-base~=3.5.0 (from bioio)
#   Downloading bioio_base-3.5.0-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: dask>=2021.4.1 in /usr/local/lib/python3.13/dist-packages (from dask[array]>=2021.4.1->bioio) (2026.8.0)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.13/dist-packages (from bioio) (2.1.3)
# Collecting ome-types>=0.4.0 (from ome-types[lxml]>=0.4.0->bioio)
#   Downloading ome_types-0.6.3-py3-none-any.whl.metadata (9.8 kB)
# Collecting semver>=3.0.1 (from bioio)
#   Downloading semver-3.1.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: fsspec!=2022.7.0,>=2021.4.0 in /usr/local/lib/python3.13/dist-packages (from bioio-base~=3.5.0->bioio) (2025.12.0)
# Collecting pint (from bioio-base~=3.5.0->bioio)
#   Downloading pint-0.26.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: xarray>=2022.6.0 in /usr/local/lib/python3.13/dist-packages (from bioio-base~=3.5.0->bioio) (2025.12.0)
# Requirement already satisfied: click>=8.1 in /usr/local/lib/python3.13/dist-packages (from dask>=2021.4.1->dask[array]>=2021.4.1->bioio) (8.5.0)
# Requirement already satisfied: cloudpickle>=3.0.0 in /usr/local/lib/python3.13/dist-packages (from dask>=2021.4.1->dask[array]>=2021.4.1->bioio) (3.1.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.13/dist-packages (from dask>=2021.4.1->dask[array]>=2021.4.1->bioio) (26.3)
# Requirement already satisfied: partd>=1.4.0 in /usr/local/lib/python3.13/dist-packages (from dask>=2021.4.1->dask[array]>=2021.4.1->bioio) (1.4.2)
# Requirement already satisfied: pyyaml>=5.4.1 in /usr/local/lib/python3.13/dist-packages (from dask>=2021.4.1->dask[array]>=2021.4.1->bioio) (6.0.3)
# Requirement already satisfied: toolz>=0.12.0 in /usr/local/lib/python3.13/dist-packages (from dask>=2021.4.1->dask[array]>=2021.4.1->bioio) (0.12.1)
# Requirement already satisfied: distributed<2026.8.1,>=2026.8.0 in /usr/local/lib/python3.13/dist-packages (from dask[array,distributed]!=2022.5.1,>=2021.4.1->bioio-base~=3.5.0->bioio) (2026.8.0)
# Requirement already satisfied: jinja2>=2.10.3 in /usr/local/lib/python3.13/dist-packages (from distributed<2026.8.1,>=2026.8.0->dask[array,distributed]!=2022.5.1,>=2021.4.1->bioio-base~=3.5.0->bioio) (3.1.6)
# Requirement already satisfied: locket>=1.0.0 in /usr/local/lib/python3.13/dist-packages (from distributed<2026.8.1,>=2026.8.0->dask[array,distributed]!=2022.5.1,>=2021.4.1->bioio-base~=3.5.0->bioio) (1.0.0)
# Requirement already satisfied: msgpack>=1.0.2 in /usr/local/lib/python3.13/dist-packages (from distributed<2026.8.1,>=2026.8.0->dask[array,distributed]!=2022.5.1,>=2021.4.1->bioio-base~=3.5.0->bioio) (1.2.2)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.13/dist-packages (from distributed<2026.8.1,>=2026.8.0->dask[array,distributed]!=2022.5.1,>=2021.4.1->bioio-base~=3.5.0->bioio) (5.9.5)
# Requirement already satisfied: sortedcontainers>=2.0.5 in /usr/local/lib/python3.13/dist-packages (from distributed<2026.8.1,>=2026.8.0->dask[array,distributed]!=2022.5.1,>=2021.4.1->bioio-base~=3.5.0->bioio) (2.4.0)
# Requirement already satisfied: tblib!=3.2.0,!=3.2.1,>=1.6.0 in /usr/local/lib/python3.13/dist-packages (from distributed<2026.8.1,>=2026.8.0->dask[array,distributed]!=2022.5.1,>=2021.4.1->bioio-base~=3.5.0->bioio) (3.2.2)
# Requirement already satisfied: tornado>=6.2.0 in /usr/local/lib/python3.13/dist-packages (from distributed<2026.8.1,>=2026.8.0->dask[array,distributed]!=2022.5.1,>=2021.4.1->bioio-base~=3.5.0->bioio) (6.5.7)
# Requirement already satisfied: zict>=3.0.0 in /usr/local/lib/python3.13/dist-packages (from distributed<2026.8.1,>=2026.8.0->dask[array,distributed]!=2022.5.1,>=2021.4.1->bioio-base~=3.5.0->bioio) (3.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.13/dist-packages (from jinja2>=2.10.3->distributed<2026.8.1,>=2026.8.0->dask[array,distributed]!=2022.5.1,>=2021.4.1->bioio-base~=3.5.0->bioio) (3.0.3)
# Requirement already satisfied: pydantic-core>=2.20.0 in /usr/local/lib/python3.13/dist-packages (from ome-types>=0.4.0->ome-types[lxml]>=0.4.0->bioio) (2.46.5)
# Collecting pydantic-extra-types>=2.0.0 (from ome-types>=0.4.0->ome-types[lxml]>=0.4.0->bioio)
#   Downloading pydantic_extra_types-2.11.1-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: pydantic>=2.4.0 in /usr/local/lib/python3.13/dist-packages (from ome-types>=0.4.0->ome-types[lxml]>=0.4.0->bioio) (2.13.5)
# Collecting xsdata>=24.4 (from ome-types>=0.4.0->ome-types[lxml]>=0.4.0->bioio)
#   Downloading xsdata-26.2-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: lxml>=4.8.0 in /usr/local/lib/python3.13/dist-packages (from ome-types[lxml]>=0.4.0->bioio) (6.1.3)
# Collecting flexcache>=0.3 (from pint->bioio-base~=3.5.0->bioio)
#   Downloading flexcache-0.3-py3-none-any.whl.metadata (7.0 kB)
# Collecting flexparser>=0.4 (from pint->bioio-base~=3.5.0->bioio)
#   Downloading flexparser-0.4-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: platformdirs>=2.1.0 in /usr/local/lib/python3.13/dist-packages (from pint->bioio-base~=3.5.0->bioio) (4.11.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.13/dist-packages (from pint->bioio-base~=3.5.0->bioio) (4.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.13/dist-packages (from pydantic>=2.4.0->ome-types>=0.4.0->ome-types[lxml]>=0.4.0->bioio) (0.8.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.13/dist-packages (from pydantic>=2.4.0->ome-types>=0.4.0->ome-types[lxml]>=0.4.0->bioio) (0.4.4)
# Requirement already satisfied: pandas>=2.2 in /usr/local/lib/python3.13/dist-packages (from xarray>=2022.6.0->bioio-base~=3.5.0->bioio) (2.2.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.13/dist-packages (from pandas>=2.2->xarray>=2022.6.0->bioio-base~=3.5.0->bioio) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.13/dist-packages (from pandas>=2.2->xarray>=2022.6.0->bioio-base~=3.5.0->bioio) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.13/dist-packages (from pandas>=2.2->xarray>=2022.6.0->bioio-base~=3.5.0->bioio) (2026.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.13/dist-packages (from python-dateutil>=2.8.2->pandas>=2.2->xarray>=2022.6.0->bioio-base~=3.5.0->bioio) (1.17.0)
# Downloading bioio-3.5.1-py3-none-any.whl (59 kB)
# Downloading bioio_base-3.5.0-py3-none-any.whl (103 kB)
# Downloading ome_types-0.6.3-py3-none-any.whl (245 kB)
# Downloading pint-0.26.1-py3-none-any.whl (326 kB)
# Downloading flexcache-0.3-py3-none-any.whl (13 kB)
# Downloading flexparser-0.4-py3-none-any.whl (27 kB)
# Downloading pydantic_extra_types-2.11.1-py3-none-any.whl (79 kB)
# Downloading semver-3.1.0-py3-none-any.whl (18 kB)
# Downloading xsdata-26.2-py3-none-any.whl (235 kB)
# Installing collected packages: xsdata, semver, flexparser, flexcache, pint, pydantic-extra-types, ome-types, bioio-base, bioio
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9/9 [bioio]
# Successfully installed bioio-3.5.1 bioio-base-3.5.0 flexcache-0.3 flexparser-0.4 ome-types-0.6.3 pint-0.26.1 pydantic-extra-types-2.11.1 semver-3.1.0 xsdata-26.2
# Collecting bioio-czi
#   Downloading bioio_czi-3.0.0-py3-none-any.whl.metadata (47 kB)
# Collecting aicspylibczi>=4.0.1 (from bioio-czi)
#   Downloading aicspylibczi-4.0.1-cp313-cp313-manylinux_2_28_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.13/dist-packages (from bioio-czi) (3.14.3)
# Requirement already satisfied: bioio-base>=3.4.0 in /usr/local/lib/python3.13/dist-packages (from bioio-czi) (3.5.0)
# Requirement already satisfied: dask>=2021.4.1 in /usr/local/lib/python3.13/dist-packages (from dask[array]>=2021.4.1->bioio-czi) (2026.8.0)
# Requirement already satisfied: fsspec>=2022.8.0 in /usr/local/lib/python3.13/dist-packages (from bioio-czi) (2025.12.0)
# Requirement already satisfied: lxml>=4.6 in /usr/local/lib/python3.13/dist-packages (from bioio-czi) (6.1.3)
# Requirement already satisfied: ome-types>=0.3.4 in /usr/local/lib/python3.13/dist-packages (from bioio-czi) (0.6.3)
# Requirement already satisfied: pylibczirw in /usr/local/lib/python3.13/dist-packages (from bioio-czi) (6.1.0)
# Requirement already satisfied: python-dateutil>=2.9.0.post0 in /usr/local/lib/python3.13/dist-packages (from bioio-czi) (2.9.0.post0)
# Requirement already satisfied: requests in /usr/local/lib/python3.13/dist-packages (from bioio-czi) (2.32.4)
# Requirement already satisfied: xarray>=2022.6.0 in /usr/local/lib/python3.13/dist-packages (from bioio-czi) (2025.12.0)
# Requirement already satisfied: numpy>=1.14.1 in /usr/local/lib/python3.13/dist-packages (from aicspylibczi>=4.0.1->bioio-czi) (2.1.3)
# Requirement already satisfied: pint in /usr/local/lib/python3.13/dist-packages (from bioio-base>=3.4.0->bioio-czi) (0.26.1)
# Requirement already satisfied: click>=8.1 in /usr/local/lib/python3.13/dist-packages (from dask>=2021.4.1->dask[array]>=2021.4.1->bioio-czi) (8.5.0)
# Requirement already satisfied: cloudpickle>=3.0.0 in /usr/local/lib/python3.13/dist-packages (from dask>=2021.4.1->dask[array]>=2021.4.1->bioio-czi) (3.1.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.13/dist-packages (from dask>=2021.4.1->dask[array]>=2021.4.1->bioio-czi) (26.3)
# Requirement already satisfied: partd>=1.4.0 in /usr/local/lib/python3.13/dist-packages (from dask>=2021.4.1->dask[array]>=2021.4.1->bioio-czi) (1.4.2)
# Requirement already satisfied: pyyaml>=5.4.1 in /usr/local/lib/python3.13/dist-packages (from dask>=2021.4.1->dask[array]>=2021.4.1->bioio-czi) (6.0.3)
# Requirement already satisfied: toolz>=0.12.0 in /usr/local/lib/python3.13/dist-packages (from dask>=2021.4.1->dask[array]>=2021.4.1->bioio-czi) (0.12.1)
# Requirement already satisfied: distributed<2026.8.1,>=2026.8.0 in /usr/local/lib/python3.13/dist-packages (from dask[array,distributed]!=2022.5.1,>=2021.4.1->bioio-base>=3.4.0->bioio-czi) (2026.8.0)
# Requirement already satisfied: jinja2>=2.10.3 in /usr/local/lib/python3.13/dist-packages (from distributed<2026.8.1,>=2026.8.0->dask[array,distributed]!=2022.5.1,>=2021.4.1->bioio-base>=3.4.0->bioio-czi) (3.1.6)
# Requirement already satisfied: locket>=1.0.0 in /usr/local/lib/python3.13/dist-packages (from distributed<2026.8.1,>=2026.8.0->dask[array,distributed]!=2022.5.1,>=2021.4.1->bioio-base>=3.4.0->bioio-czi) (1.0.0)
# Requirement already satisfied: msgpack>=1.0.2 in /usr/local/lib/python3.13/dist-packages (from distributed<2026.8.1,>=2026.8.0->dask[array,distributed]!=2022.5.1,>=2021.4.1->bioio-base>=3.4.0->bioio-czi) (1.2.2)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.13/dist-packages (from distributed<2026.8.1,>=2026.8.0->dask[array,distributed]!=2022.5.1,>=2021.4.1->bioio-base>=3.4.0->bioio-czi) (5.9.5)
# Requirement already satisfied: sortedcontainers>=2.0.5 in /usr/local/lib/python3.13/dist-packages (from distributed<2026.8.1,>=2026.8.0->dask[array,distributed]!=2022.5.1,>=2021.4.1->bioio-base>=3.4.0->bioio-czi) (2.4.0)
# Requirement already satisfied: tblib!=3.2.0,!=3.2.1,>=1.6.0 in /usr/local/lib/python3.13/dist-packages (from distributed<2026.8.1,>=2026.8.0->dask[array,distributed]!=2022.5.1,>=2021.4.1->bioio-base>=3.4.0->bioio-czi) (3.2.2)
# Requirement already satisfied: tornado>=6.2.0 in /usr/local/lib/python3.13/dist-packages (from distributed<2026.8.1,>=2026.8.0->dask[array,distributed]!=2022.5.1,>=2021.4.1->bioio-base>=3.4.0->bioio-czi) (6.5.7)
# Requirement already satisfied: zict>=3.0.0 in /usr/local/lib/python3.13/dist-packages (from distributed<2026.8.1,>=2026.8.0->dask[array,distributed]!=2022.5.1,>=2021.4.1->bioio-base>=3.4.0->bioio-czi) (3.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.13/dist-packages (from jinja2>=2.10.3->distributed<2026.8.1,>=2026.8.0->dask[array,distributed]!=2022.5.1,>=2021.4.1->bioio-base>=3.4.0->bioio-czi) (3.0.3)
# Requirement already satisfied: pydantic-core>=2.20.0 in /usr/local/lib/python3.13/dist-packages (from ome-types>=0.3.4->bioio-czi) (2.46.5)
# Requirement already satisfied: pydantic-extra-types>=2.0.0 in /usr/local/lib/python3.13/dist-packages (from ome-types>=0.3.4->bioio-czi) (2.11.1)
# Requirement already satisfied: pydantic>=2.4.0 in /usr/local/lib/python3.13/dist-packages (from ome-types>=0.3.4->bioio-czi) (2.13.5)
# Requirement already satisfied: xsdata>=24.4 in /usr/local/lib/python3.13/dist-packages (from ome-types>=0.3.4->bioio-czi) (26.2)
# Requirement already satisfied: flexcache>=0.3 in /usr/local/lib/python3.13/dist-packages (from pint->bioio-base>=3.4.0->bioio-czi) (0.3)
# Requirement already satisfied: flexparser>=0.4 in /usr/local/lib/python3.13/dist-packages (from pint->bioio-base>=3.4.0->bioio-czi) (0.4)
# Requirement already satisfied: platformdirs>=2.1.0 in /usr/local/lib/python3.13/dist-packages (from pint->bioio-base>=3.4.0->bioio-czi) (4.11.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.13/dist-packages (from pint->bioio-base>=3.4.0->bioio-czi) (4.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.13/dist-packages (from pydantic>=2.4.0->ome-types>=0.3.4->bioio-czi) (0.8.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.13/dist-packages (from pydantic>=2.4.0->ome-types>=0.3.4->bioio-czi) (0.4.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.13/dist-packages (from python-dateutil>=2.9.0.post0->bioio-czi) (1.17.0)
# Requirement already satisfied: pandas>=2.2 in /usr/local/lib/python3.13/dist-packages (from xarray>=2022.6.0->bioio-czi) (2.2.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.13/dist-packages (from pandas>=2.2->xarray>=2022.6.0->bioio-czi) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.13/dist-packages (from pandas>=2.2->xarray>=2022.6.0->bioio-czi) (2026.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp->bioio-czi) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp->bioio-czi) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp->bioio-czi) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.13/dist-packages (from aiohttp->bioio-czi) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.13/dist-packages (from aiohttp->bioio-czi) (6.8.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp->bioio-czi) (0.5.4)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp->bioio-czi) (1.25.1)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.13/dist-packages (from yarl<2.0,>=1.17.0->aiohttp->bioio-czi) (3.19)
# Requirement already satisfied: cmake in /usr/local/lib/python3.13/dist-packages (from pylibczirw->bioio-czi) (3.31.10)
# Requirement already satisfied: xmltodict in /usr/local/lib/python3.13/dist-packages (from pylibczirw->bioio-czi) (1.0.4)
# Requirement already satisfied: validators in /usr/local/lib/python3.13/dist-packages (from pylibczirw->bioio-czi) (0.35.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests->bioio-czi) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.13/dist-packages (from requests->bioio-czi) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.13/dist-packages (from requests->bioio-czi) (2026.7.22)
# Downloading bioio_czi-3.0.0-py3-none-any.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 43.0 MB/s  0:00:00
# Downloading aicspylibczi-4.0.1-cp313-cp313-manylinux_2_28_x86_64.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 58.3 MB/s  0:00:00
# Installing collected packages: aicspylibczi, bioio-czi
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [bioio-czi]
# Successfully installed aicspylibczi-4.0.1 bioio-czi-3.0.0
# Collecting scikit_posthocs
#   Downloading scikit_posthocs-0.17.0-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.13/dist-packages (from scikit_posthocs) (2.1.3)
# Requirement already satisfied: scipy>=1.9.0 in /usr/local/lib/python3.13/dist-packages (from scikit_posthocs) (1.16.3)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.13/dist-packages (from scikit_posthocs) (0.15.0)
# Requirement already satisfied: pandas>=0.20.0 in /usr/local/lib/python3.13/dist-packages (from scikit_posthocs) (2.2.3)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.13/dist-packages (from scikit_posthocs) (0.13.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.13/dist-packages (from scikit_posthocs) (3.10.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.13/dist-packages (from pandas>=0.20.0->scikit_posthocs) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.13/dist-packages (from pandas>=0.20.0->scikit_posthocs) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.13/dist-packages (from pandas>=0.20.0->scikit_posthocs) (2026.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.13/dist-packages (from python-dateutil>=2.8.2->pandas>=0.20.0->scikit_posthocs) (1.17.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib->scikit_posthocs) (1.4.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.13/dist-packages (from matplotlib->scikit_posthocs) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.13/dist-packages (from matplotlib->scikit_posthocs) (4.65.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib->scikit_posthocs) (1.5.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.13/dist-packages (from matplotlib->scikit_posthocs) (26.3)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.13/dist-packages (from matplotlib->scikit_posthocs) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib->scikit_posthocs) (3.3.2)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.13/dist-packages (from statsmodels->scikit_posthocs) (1.0.3)
# Requirement already satisfied: formulaic>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from statsmodels->scikit_posthocs) (1.2.2)
# Requirement already satisfied: interface-meta>=1.2.0 in /usr/local/lib/python3.13/dist-packages (from formulaic>=1.1.0->statsmodels->scikit_posthocs) (2.0.1)
# Requirement already satisfied: narwhals>=1.17 in /usr/local/lib/python3.13/dist-packages (from formulaic>=1.1.0->statsmodels->scikit_posthocs) (2.26.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.13/dist-packages (from formulaic>=1.1.0->statsmodels->scikit_posthocs) (4.16.0)
# Requirement already satisfied: wrapt>=1.17.0rc1 in /usr/local/lib/python3.13/dist-packages (from formulaic>=1.1.0->statsmodels->scikit_posthocs) (2.4.1)
# Downloading scikit_posthocs-0.17.0-py3-none-any.whl (46 kB)
# Installing collected packages: scikit_posthocs
# Successfully installed scikit_posthocs-0.17.0
# Requirement already satisfied: zarr in /usr/local/lib/python3.13/dist-packages (3.4.0)
# Requirement already satisfied: donfig>=0.8 in /usr/local/lib/python3.13/dist-packages (from zarr) (0.8.1.post1)
# Requirement already satisfied: google-crc32c>=1.5 in /usr/local/lib/python3.13/dist-packages (from zarr) (1.8.0)
# Requirement already satisfied: msgspec>=0.19 in /usr/local/lib/python3.13/dist-packages (from zarr) (0.21.1)
# Requirement already satisfied: numcodecs>=0.14 in /usr/local/lib/python3.13/dist-packages (from zarr) (0.17.0)
# Requirement already satisfied: numpy>=2 in /usr/local/lib/python3.13/dist-packages (from zarr) (2.1.3)
# Requirement already satisfied: packaging>=22.0 in /usr/local/lib/python3.13/dist-packages (from zarr) (26.3)
# Requirement already satisfied: typing-extensions>=4.14 in /usr/local/lib/python3.13/dist-packages (from zarr) (4.16.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.13/dist-packages (from donfig>=0.8->zarr) (6.0.3)
# Collecting statannotations
#   Downloading statannotations-0.7.2-py3-none-any.whl.metadata (7.7 kB)
# Requirement already satisfied: numpy>=1.12.1 in /usr/local/lib/python3.13/dist-packages (from statannotations) (2.1.3)
# Requirement already satisfied: seaborn>=0.9.0 in /usr/local/lib/python3.13/dist-packages (from statannotations) (0.13.2)
# Requirement already satisfied: matplotlib>=2.2.2 in /usr/local/lib/python3.13/dist-packages (from statannotations) (3.10.0)
# Requirement already satisfied: pandas>=0.23.0 in /usr/local/lib/python3.13/dist-packages (from statannotations) (2.2.3)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from statannotations) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=2.2.2->statannotations) (1.4.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=2.2.2->statannotations) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=2.2.2->statannotations) (4.65.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=2.2.2->statannotations) (1.5.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=2.2.2->statannotations) (26.3)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=2.2.2->statannotations) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=2.2.2->statannotations) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=2.2.2->statannotations) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.13/dist-packages (from pandas>=0.23.0->statannotations) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.13/dist-packages (from pandas>=0.23.0->statannotations) (2026.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.13/dist-packages (from python-dateutil>=2.7->matplotlib>=2.2.2->statannotations) (1.17.0)
# Downloading statannotations-0.7.2-py3-none-any.whl (39 kB)
# Installing collected packages: statannotations
# Successfully installed statannotations-0.7.2
# Cloning into 'FRAP-analysis-younglab'...
# remote: Enumerating objects: 387, done.
# remote: Counting objects: 100% (124/124), done.
# remote: Compressing objects: 100% (92/92), done.
# remote: Total 387 (delta 62), reused 82 (delta 30), pack-reused 263 (from 1)
# Receiving objects: 100% (387/387), 235.18 MiB | 25.24 MiB/s, done.
# Resolving deltas: 100% (192/192), done.
# Updating files: 100% (55/55), done.
# /content/FRAP-analysis-younglab
# env/  README.md  sample_images/  src/
# From https://github.com/amarcosv/FRAP-analysis-younglab
#  * branch            develop    -> FETCH_HEAD
# Already up to date.
# /content/FRAP-analysis-younglab/src

# %% [markdown]
# # **Mount Google Drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Run analysis

# %% [markdown]
# ## **Define input folder**

# %%
input_folder_paths = ["/content/FRAP-analysis-younglab/sample_images/CSV/MUT",
                      "/content/FRAP-analysis-younglab/sample_images/CSV/MUT2",
                      "/content/FRAP-analysis-younglab/sample_images/CSV/WT"]



output_path = "/content/drive/MyDrive/Young_Lab/20260113_Rett_iPSC_Buc/test_asier"

do_whole_cell = False  #False = reference from czi file ROI / True =  use whole cell as reference
exp_fitting_order = 1 # 1 for monoexponential /  2 for biexponential




#Check data integrity
for idx, f in enumerate(input_folder_paths):
  if os.path.isdir(f):
      print(f"Input folder :'{f}'")
  else:
      print('\033[31m' + f"WARNING: The folder '{f}' does not exist." + '\033[0m')

if os.path.isdir(output_path):
      print(f"Path to output data: '{f}'")
else:
      print('\033[31m' + f"WARNING: The output folder '{f}' does not exist." + '\033[0m')
# Out:
# Input folder :'/content/FRAP-analysis-younglab/sample_images/CSV/MUT'
# Input folder :'/content/FRAP-analysis-younglab/sample_images/CSV/MUT2'
# Input folder :'/content/FRAP-analysis-younglab/sample_images/CSV/WT'
# Path to output data: '/content/FRAP-analysis-younglab/sample_images/CSV/WT'

# %% [markdown]
# ## Launch analysis and plot results

# %%
roiData = []
frap_experiment = []
wt_preview = []

for idx,folderPath in enumerate(input_folder_paths):

    #print('Processing files from directory: ' + folderPath)
    dataset_roiData, dataset_frap_experiment, wt_preview = frap_tools.process_FRAP_folder(folderPath, wcell_corr= do_whole_cell, fitting_exp = exp_fitting_order)
    print(os.path.dirname(folderPath))
    dataset_roiData.insert(loc=0, column = 'folder', value = os.path.basename(folderPath))
    dataset_frap_experiment.insert(loc=0, column = 'folder', value = os.path.basename(folderPath))
    roiData.append(dataset_roiData)
    frap_experiment.append(dataset_frap_experiment)
    io_tools.saveResults(os.path.join(output_path,os.path.basename(folderPath)), dataset_roiData, dataset_frap_experiment)



nrows = 6 + 2* len(input_folder_paths)
nd = len(input_folder_paths)
ax = []
#Color palette for multiple groups
palette = sns.color_palette("tab10")
#color palette for dishes
n_base_colors = 15
base_palette = sns.color_palette("husl", n_base_colors)
dish_palette = {str(i + 1): base_palette[i % n_base_colors] for i in range(200)}



#PLOT results
fig = plt.figure(constrained_layout=True, figsize=(12, nrows*3))
# hspace is passed directly to the gridspec (rather than via plt.subplots_adjust)
# since the constrained_layout engine ignores/warns on subplots_adjust
spec = fig.add_gridspec(nrows, 4, hspace=0.4)

# PLOT raw data per folder and dish
for i in range(nd):
    ax = fig.add_subplot(spec[i, :])
    sns.lineplot(ax = ax, data =roiData[i], x= 'timestamp_frap_r', y = 'frap_norm_r', hue = 'dish', palette=dish_palette )
    ax.set_title(os.path.basename(input_folder_paths[i]) + ' per dish recovery curves', parse_math=False)
    ax.set_ylabel('Raw intensity')
    ax.set_xlabel('Time[s]')
    ax.margins(x=0)
    sns.move_legend(ax, "lower right", frameon=False)
#ax.legend(title = 'dish',frameon=False)


# PLOT raw data all together
ax = fig.add_subplot(spec[nd, :])
for i in range(nd):
        sns.lineplot(ax = ax, data =roiData[i], x= 'timestamp_frap_r', y = 'frap_norm_r',  label = os.path.basename(input_folder_paths[i]) , color=palette[i])
ax.set_title(os.path.basename(input_folder_paths[i]) + ' per dish recovery curves', parse_math=False)
ax.set_ylabel('Raw intensity')
ax.set_xlabel('Time[s]')
ax.margins(x=0)
sns.move_legend(ax, "lower right", frameon=False)

# PLOT Boxplots for mobile fraction and tau1/2
ax = fig.add_subplot(spec[nd+1: nd+3,0:2])
for i in range(nd):
    sns.boxplot(ax = ax, data = frap_experiment[i], x="folder", y="mob", label = os.path.basename(input_folder_paths[i]), color=palette[i])
ax.set_title('Mobile fraction')
ax.set_ylabel('Mobile fraction')
ax.set_xlabel(None)
#ax.set(ylim=( 0,1.3))
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1),frameon=False)

ax = fig.add_subplot(spec[nd+1:nd+3,2::])
for i in range(nd):
    sns.boxplot(ax = ax, data = frap_experiment[i], x="folder", y="half_max", label = os.path.basename(input_folder_paths[i]), color=palette[i])
ax.set_title('Recovery half max ')
ax.set_ylabel(r'$\tau^{1/2}$ [s]')
ax.set_xlabel(None)
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1),frameon=False)
#ax.set(ylim=( 0,4))



# PLOT Mobile fraction per dish
ax = fig.add_subplot(spec[nd+3, :])
for i in range(nd):
    #Fix bug with seaborn where if there is a single dish the dodge parameter needs to be set to false for pointplot or will crash
    n_dish=len(frap_experiment[i]['dish'].unique())
    if n_dish == 1: dodge_param = False
    else: dodge_param = .4

    sns.stripplot(ax = ax, data = frap_experiment[i], x="folder", y="mob", hue = "dish",
        dodge=dodge_param, alpha=.2, legend=False, palette = dish_palette)
    sns.pointplot(ax = ax, data = frap_experiment[i], x="folder", y="mob", hue = "dish",
    dodge=dodge_param, linestyle="none", errorbar=None, marker="_", markersize=20, markeredgewidth=3,  palette=dish_palette)
ax.set_title('Mobile fraction per dish')
ax.set_ylabel('Mobile fraction')
ax.set_xlabel(None)
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1),frameon=False)
#plt.show()


# PLOT tau 1/2  per dish
ax = fig.add_subplot(spec[nd+4, :])
for i in range(nd):
    #Fix bug with seaborn where if there is a single dish the dodge parameter needs to be set to false for pointplot or will crash
    n_dish=len(frap_experiment[i]['dish'].unique())
    if n_dish == 1: dodge_param = False
    else: dodge_param = .4

    sns.stripplot(ax = ax, data = frap_experiment[i], x="folder", y="half_max", hue = "dish",
        dodge=dodge_param, alpha=.2, legend=False, palette="Set2" )

    sns.pointplot(ax = ax, data = frap_experiment[i], x="folder", y="half_max", hue = "dish",
    dodge=dodge_param, linestyle="none", errorbar=None, marker="_", markersize=20, markeredgewidth=3, palette="Set2")
ax.set_title('Recovery half max per dish')
ax.set_ylabel(r'$\tau^{1/2}$ [s]')
ax.set_xlabel(None)
ax.legend(title='dish')
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1),frameon=False)


# PLOT FRAP recovery full scale per group
ax = fig.add_subplot(spec[nd+5 , :])
for i in range(nd):
    sns.lineplot(ax = ax, data =roiData[i], x= 'timestamp_frap_r', y = 'frap_fullscale_norm_r', label = os.path.basename(input_folder_paths[i]), errorbar = 'se')
    #sns.lineplot(ax = ax, data =roiData[i], x= 'timestamp_frap_r', y = 'frap_fullscale_norm_r', label = os.path.basename(input_folder_paths[i]) ,errorbar = 'se')
ax.set_title('Full scale FRAP recovery')
ax.set_ylabel('Full scale Normalized intensity')
ax.set_xlabel('Time[s]')
ax.margins(x=0)
sns.move_legend(ax, "lower right", frameon=False)


# PLOT FRAP recovery full scale per group and dish
for i in range(nd):
    ax = fig.add_subplot(spec[nd+6 + i, :])
    sns.scatterplot(ax = ax, data =roiData[i][roiData[i]['timepoint_frap']>=0], x= 'timestamp_frap_r', y = 'frap_norm_r',
                alpha = 0.1, color=palette[i], legend = None)
    sns.lineplot(ax = ax, data =roiData[i][roiData[i]['timepoint_frap']>=0], x= 'timestamp_frap_r', y = 'frap_norm_r', label = os.path.basename(input_folder_paths[i]),
                errorbar = 'sd', err_style = 'bars', color=palette[i])
    ax.set_title('Full scale recovery - ' + os.path.basename(input_folder_paths[i]), parse_math=False)
    ax.set_ylabel('Full scale Normalized intensity')
    ax.set_xlabel('Time[s]')
    sns.move_legend(ax, "lower right", frameon=False)


basenames =  [os.path.basename(f) for f in input_folder_paths]
outputName = "_".join(basenames)

fig.savefig(os.path.join(output_path,outputName + 'frap_results.pdf'), bbox_inches='tight', dpi=300)

# %%
basenames = [os.path.basename(f) for f in input_folder_paths]

processing_tools.run_dish_aggregated_comparison(frap_experiment, basenames, 'mob', 'Mobile Fraction')
processing_tools.run_dish_aggregated_comparison(frap_experiment, basenames, 'half_max', 'Recovery Half Max')

# %% [markdown]
# ##Build QC plots for each analyzed experiment

# %%
# QC: per-file diagnostic plots (reference fit + recovery curve) as a single PDF

# Combine per-folder roiData / frap_experiment into single long DataFrames,
# one row per timepoint (roiData) / one row per file (frap_experiment)
roiData_all = pd.concat(roiData, ignore_index=True)
frap_experiment_all = pd.concat(frap_experiment, ignore_index=True)
files = sorted(roiData_all['file'].unique())
n_files = len(files)

fig, axes = plt.subplots(n_files, 2, figsize=(12, 3 * n_files), squeeze=False)

for i, f in enumerate(files):
    df_f = roiData_all[roiData_all['file'] == f]

    # Label with folder/dish too, if available, for easier traceability
    label_bits = [f]
    if 'folder' in df_f.columns:
        label_bits.append(str(df_f['folder'].iloc[0]))
    if 'dish' in df_f.columns:
        label_bits.append(f"dish {df_f['dish'].iloc[0]}")
    row_label = " | ".join(label_bits)

    # Matching row in frap_experiment for this file (mob / half_max / recovery fit values)
    fit_row = frap_experiment_all[frap_experiment_all['file'] == f]

    # Left column: reference (points) & reference_synth (line) vs full timestamp_frap range
    ax_left = axes[i, 0]
    ax_left.plot(df_f['timestamp_frap'], df_f['reference'], marker='o', linestyle='-',
                 markersize=3.0, linewidth=1, color='tab:gray', label='reference')
    ax_left.plot(df_f['timestamp_frap'], df_f['reference_synth'], color='tab:red',
                 label='reference_synth')
    # parse_math=False: row_label comes from filenames/folders, which may contain
    # characters (e.g. '#', an even count of '$') that matplotlib would otherwise
    # misinterpret as mathtext and fail to parse.
    ax_left.set_title(row_label + '\nreference', fontsize=9, parse_math=False)
    ax_left.set_xlabel('Time [s]')
    ax_left.set_ylabel('Intensity')
    ax_left.margins(x=0)
    ax_left.legend(frameon=False, fontsize=7, loc='best')

    # Right column: bleach_recovery_curve (line) & frap_norm (points), timestamp_frap > 0 only
    df_pos = df_f[df_f['timestamp_frap'] > 0]
    ax_right = axes[i, 1]
    ax_right.plot(df_pos['timestamp_frap'], df_pos['bleach_recovery_curve'],
                  color='tab:orange', label='bleach_recovery_curve')
    ax_right.plot(df_pos['timestamp_frap'], df_pos['frap_norm'], marker='o', linestyle='-',
                  markersize=3.0, linewidth=1, color='tab:blue', label='frap_norm')

    if not fit_row.empty:
        # Mark fitted mobile fraction (horizontal) and recovery half-max time (vertical)
        mob_val = fit_row['mob'].iloc[0]
        half_max_val = fit_row['half_max'].iloc[0]
        ax_right.axhline(mob_val, color='tab:green', linestyle='--', linewidth=1,
                          label=f'mob = {mob_val:.2f}')
        ax_right.axvline(half_max_val, color='tab:purple', linestyle='--', linewidth=1,
                          label=f'half_max = {half_max_val:.2f}')

        # Print the fitted exponential recovery equation and its R^2
        y0, A, tau = fit_row['recovery_fit'].iloc[0]
        r2 = fit_row['recovery_fit_r2'].iloc[0]
        eq_text = (rf"$Y = {y0:.3f} + {A:.3f}\,e^{{-{tau:.3f}\,t}}$" "\n"
                   f"$R^2 = {r2:.3f}$")
        ax_right.text(0.98, 0.02, eq_text, transform=ax_right.transAxes,
                      fontsize=7, ha='right', va='bottom',
                      bbox=dict(boxstyle='round', facecolor='white', alpha=0.75, edgecolor='0.7'))

    ax_right.set_title(row_label + '\nrecovery', fontsize=9, parse_math=False)
    ax_right.set_xlabel('Time [s]')
    ax_right.set_ylabel('Normalized intensity')
    ax_right.margins(x=0)
    ax_right.legend(frameon=False, fontsize=7, loc='best')

plt.tight_layout()

qc_pdf_path = os.path.join(output_path, 'QC_per_file.pdf')
fig.savefig(qc_pdf_path, bbox_inches='tight', dpi=150)
plt.close(fig)

print(f"QC PDF saved to: {qc_pdf_path}  ({n_files} files)")
